# %% [markdown]
# **NLTK POC**

# %% [markdown]
# "NLTK is a leading platform for building Python programs to work with human language data. It provides easy-to-use interfaces to over 50 corpora and lexical resources such as WordNet, along with a suite of text processing libraries for classification, tokenization, stemming, tagging, parsing, and semantic reasoning, wrappers for industrial-strength NLP libraries, and an active discussion forum." - NLTK Documentation

# %%
# NB: since NLTK is large, not all available packages are installed by default

import nltk 
from nltk.tokenize import word_tokenize
# nltk.download('punkt')
from nltk.corpus import stopwords
# nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
# nltk.download('wordnet')
# nltk.download('averaged_perceptron_tagger')
from nltk.sentiment import SentimentIntensityAnalyzer
# nltk.download('vader_lexicon')

# %%
# article: https://apnews.com/article/technology-misinformation-eastern-europe-902f436e3a6507e8b2a223e09a22e969

article = open("article.txt", "r", encoding='utf-8')
text = article.read()
print(text)
# Out:
# Soon after the Russian invasion, the hoaxes began. Ukrainian refugees were taking jobs, committing crimes and abusing handouts. The misinformation spread rapidly online throughout Eastern Europe, sometimes pushed by Moscow in an effort to destabilize its neighbors.
#
# It’s the kind of swift spread of falsehoods that has been blamed in many countries for increased polarization and an erosion of trust in democratic institutions, journalism and science.
#
# But countering or stopping misinformation has proven elusive.
#
# New findings from university researchers and Google, however, reveal that one of the most promising responses to misinformation may also be one of the simplest.
#
# In a paper published Wednesday in the journal Science Advances, the researchers detail how short online videos that teach basic critical thinking skills can make people better able to resist misinformation.
#
# The researchers created a series of videos similar to a public service announcement that focused on specific misinformation techniques — characteristics seen in many common false claims that include emotionally charged language, personal attacks or false comparisons between two unrelated items.
#
# Researchers then gave people a series of claims and found that those who watched the videos were significantly better at distinguishing false information from accurate information.
#
# It’s an approach called “pre-bunking” and it builds on years of research into an idea known as inoculation theory that suggests exposing people to how misinformation works, using harmless, fictional examples, can boost their defenses to false claims.
#
# With the findings in hand, Google plans to roll out a series of pre-bunking videos soon in Eastern Europe focused on scapegoating, which can be seen in much of the misinformation about Ukrainian refugees. That focus was chosen by Jigsaw, a division of Google that works to find new ways to address misinformation and extremism.
#
# “We have spent quite a bit of time and energy studying the problem,” said Beth Goldberg, Jigsaw’s head of research and one of the authors of the paper. “We started thinking: How can we make the users, the people online, more resilient to misinformation?”
#
# The two-minute clips then demonstrate how these tactics can show up in headlines, or social media posts, to make a person believe something that isn’t true.
#
# They’re surprisingly effective. Subjects who viewed the videos were found to be significantly better at distinguishing false claims from accurate information when tested by the researchers. The same positive results occurred when the experiment was replicated on YouTube, where nearly 1 million people viewed the videos.
#
# Researchers are now investigating how long the effects last, and whether “booster” videos can help sustain the benefits.
#
# Earlier findings have suggested that online games or tutorials that teach critical thinking skills can also improve resiliency to misinformation. But videos, which could be played alongside online advertisements, are likely to reach many more people, said Jon Roozenbeek, a Cambridge University professor and one of the authors of the study.
#
# Other authors included researchers at the University of Bristol in the U.K. and the University of Western Australia.
#
# Google’s effort will be one of the largest real-world tests of pre-bunking so far. The videos will be released on YouTube, Facebook and TikTok, in Poland, the Czech Republic and Slovakia. All three countries have accepted large numbers of Ukrainian refugees and their citizens could be vulnerable to misinformation about refugees.
#
# Jigsaw CEO Yasmin Green said the work on prebunking is intended to complement Google’s other efforts to reduce the spread of misinformation: “As the scourge of misinformation grows, there’s a lot more we can do to provide people with prompts and features that help them stay safe and informed online.”
#
# While journalistic fact checks can be effective in debunking a particular piece of misinformation, they’re time and labor intensive. By focusing on characteristics of misinformation in general instead of specific claims, pre-bunking videos can help a person spot false claims on a wider variety of topics.
#
# Another method, content moderation by social media companies, can often be inconsistent. While platforms like Facebook and Twitter often remove misinformation that violates their rules, they’re also criticized for failing to do more. Other platforms like Telegram or Gab boast a largely hands-off approach to misinformation.
#
# Social media content moderation and journalistic fact checks can also run the risk of alienating those who believe the misinformation. They might also be ignored by people who already distrust legitimate news outlets.
#
# “The word fact checking itself has become politicized,” Roozenbeek said.
#
# Pre-bunking videos, however, don’t target specific claims, and they make no assertions about what is true or not. Instead, they teach the viewer how false claims work in general — whether it’s a claim about elections or NASA’s moon landings, or the latest outbreak of the avian flu.
#
# That transferability makes pre-bunking a particularly effective way of confronting misinformation, according to John Cook, a research professor at Australia’s Monash University who has created online games that teach ways to spot misinformation.
#
# “We’ve done enough research to know this can be effective,” Cook said. “What we need now is the resources to deploy this at scale.”

# %% [markdown]
# BASICS

# %%
sentences = nltk.sent_tokenize(text)
print(len(sentences))
# Out:
# 37

# %%
words = nltk.word_tokenize(text)
print(len(words))
# Out:
# 964

# %% [markdown]
# TOKENIZATION

# %%
tokenized = word_tokenize(text)

tokenized = [token.lower() for token in tokenized]

print(tokenized)
# Out:
# ['soon', 'after', 'the', 'russian', 'invasion', ',', 'the', 'hoaxes', 'began', '.', 'ukrainian', 'refugees', 'were', 'taking', 'jobs', ',', 'committing', 'crimes', 'and', 'abusing', 'handouts', '.', 'the', 'misinformation', 'spread', 'rapidly', 'online', 'throughout', 'eastern', 'europe', ',', 'sometimes', 'pushed', 'by', 'moscow', 'in', 'an', 'effort', 'to', 'destabilize', 'its', 'neighbors', '.', 'it', '’', 's', 'the', 'kind', 'of', 'swift', 'spread', 'of', 'falsehoods', 'that', 'has', 'been', 'blamed', 'in', 'many', 'countries', 'for', 'increased', 'polarization', 'and', 'an', 'erosion', 'of', 'trust', 'in', 'democratic', 'institutions', ',', 'journalism', 'and', 'science', '.', 'but', 'countering', 'or', 'stopping', 'misinformation', 'has', 'proven', 'elusive', '.', 'new', 'findings', 'from', 'university', 'researchers', 'and', 'google', ',', 'however', ',', 'reveal', 'that', 'one', 'of', 'the', 'most', 'promising', 'responses', 'to', 'misinformation', 'may', 'also', 'be', 'one', 'of', 'the', 'simplest', '.', 'in', 'a', 'paper', 'published', 'wednesday', 'in', 'the', 'journal', 'science', 'advances', ',', 'the', 'researchers', 'detail', 'how', 'short', 'online', 'videos', 'that', 'teach', 'basic', 'critical', 'thinking', 'skills', 'can', 'make', 'people', 'better', 'able', 'to', 'resist', 'misinformation', '.', 'the', 'researchers', 'created', 'a', 'series', 'of', 'videos', 'similar', 'to', 'a', 'public', 'service', 'announcement', 'that', 'focused', 'on', 'specific', 'misinformation', 'techniques', '—', 'characteristics', 'seen', 'in', 'many', 'common', 'false', 'claims', 'that', 'include', 'emotionally', 'charged', 'language', ',', 'personal', 'attacks', 'or', 'false', 'comparisons', 'between', 'two', 'unrelated', 'items', '.', 'researchers', 'then', 'gave', 'people', 'a', 'series', 'of', 'claims', 'and', 'found', 'that', 'those', 'who', 'watched', 'the', 'videos', 'were', 'significantly', 'better', 'at', 'distinguishing', 'false', 'information', 'from', 'accurate', 'information', '.', 'it', '’', 's', 'an', 'approach', 'called', '“', 'pre-bunking', '”', 'and', 'it', 'builds', 'on', 'years', 'of', 'research', 'into', 'an', 'idea', 'known', 'as', 'inoculation', 'theory', 'that', 'suggests', 'exposing', 'people', 'to', 'how', 'misinformation', 'works', ',', 'using', 'harmless', ',', 'fictional', 'examples', ',', 'can', 'boost', 'their', 'defenses', 'to', 'false', 'claims', '.', 'with', 'the', 'findings', 'in', 'hand', ',', 'google', 'plans', 'to', 'roll', 'out', 'a', 'series', 'of', 'pre-bunking', 'videos', 'soon', 'in', 'eastern', 'europe', 'focused', 'on', 'scapegoating', ',', 'which', 'can', 'be', 'seen', 'in', 'much', 'of', 'the', 'misinformation', 'about', 'ukrainian', 'refugees', '.', 'that', 'focus', 'was', 'chosen', 'by', 'jigsaw', ',', 'a', 'division', 'of', 'google', 'that', 'works', 'to', 'find', 'new', 'ways', 'to', 'address', 'misinformation', 'and', 'extremism', '.', '“', 'we', 'have', 'spent', 'quite', 'a', 'bit', 'of', 'time', 'and', 'energy', 'studying', 'the', 'problem', ',', '”', 'said', 'beth', 'goldberg', ',', 'jigsaw', '’', 's', 'head', 'of', 'research', 'and', 'one', 'of', 'the', 'authors', 'of', 'the', 'paper', '.', '“', 'we', 'started', 'thinking', ':', 'how', 'can', 'we', 'make', 'the', 'users', ',', 'the', 'people', 'online', ',', 'more', 'resilient', 'to', 'misinformation', '?', '”', 'the', 'two-minute', 'clips', 'then', 'demonstrate', 'how', 'these', 'tactics', 'can', 'show', 'up', 'in', 'headlines', ',', 'or', 'social', 'media', 'posts', ',', 'to', 'make', 'a', 'person', 'believe', 'something', 'that', 'isn', '’', 't', 'true', '.', 'they', '’', 're', 'surprisingly', 'effective', '.', 'subjects', 'who', 'viewed', 'the', 'videos', 'were', 'found', 'to', 'be', 'significantly', 'better', 'at', 'distinguishing', 'false', 'claims', 'from', 'accurate', 'information', 'when', 'tested', 'by', 'the', 'researchers', '.', 'the', 'same', 'positive', 'results', 'occurred', 'when', 'the', 'experiment', 'was', ...

# %% [markdown]
# STOP WORD REMOVAL

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
filtered = [word for word in tokenized if word not in stopwords.words('english')]

print(filtered)
# Out:
# ['soon', 'russian', 'invasion', ',', 'hoaxes', 'began', '.', 'ukrainian', 'refugees', 'taking', 'jobs', ',', 'committing', 'crimes', 'abusing', 'handouts', '.', 'misinformation', 'spread', 'rapidly', 'online', 'throughout', 'eastern', 'europe', ',', 'sometimes', 'pushed', 'moscow', 'effort', 'destabilize', 'neighbors', '.', '’', 'kind', 'swift', 'spread', 'falsehoods', 'blamed', 'many', 'countries', 'increased', 'polarization', 'erosion', 'trust', 'democratic', 'institutions', ',', 'journalism', 'science', '.', 'countering', 'stopping', 'misinformation', 'proven', 'elusive', '.', 'new', 'findings', 'university', 'researchers', 'google', ',', 'however', ',', 'reveal', 'one', 'promising', 'responses', 'misinformation', 'may', 'also', 'one', 'simplest', '.', 'paper', 'published', 'wednesday', 'journal', 'science', 'advances', ',', 'researchers', 'detail', 'short', 'online', 'videos', 'teach', 'basic', 'critical', 'thinking', 'skills', 'make', 'people', 'better', 'able', 'resist', 'misinformation', '.', 'researchers', 'created', 'series', 'videos', 'similar', 'public', 'service', 'announcement', 'focused', 'specific', 'misinformation', 'techniques', '—', 'characteristics', 'seen', 'many', 'common', 'false', 'claims', 'include', 'emotionally', 'charged', 'language', ',', 'personal', 'attacks', 'false', 'comparisons', 'two', 'unrelated', 'items', '.', 'researchers', 'gave', 'people', 'series', 'claims', 'found', 'watched', 'videos', 'significantly', 'better', 'distinguishing', 'false', 'information', 'accurate', 'information', '.', '’', 'approach', 'called', '“', 'pre-bunking', '”', 'builds', 'years', 'research', 'idea', 'known', 'inoculation', 'theory', 'suggests', 'exposing', 'people', 'misinformation', 'works', ',', 'using', 'harmless', ',', 'fictional', 'examples', ',', 'boost', 'defenses', 'false', 'claims', '.', 'findings', 'hand', ',', 'google', 'plans', 'roll', 'series', 'pre-bunking', 'videos', 'soon', 'eastern', 'europe', 'focused', 'scapegoating', ',', 'seen', 'much', 'misinformation', 'ukrainian', 'refugees', '.', 'focus', 'chosen', 'jigsaw', ',', 'division', 'google', 'works', 'find', 'new', 'ways', 'address', 'misinformation', 'extremism', '.', '“', 'spent', 'quite', 'bit', 'time', 'energy', 'studying', 'problem', ',', '”', 'said', 'beth', 'goldberg', ',', 'jigsaw', '’', 'head', 'research', 'one', 'authors', 'paper', '.', '“', 'started', 'thinking', ':', 'make', 'users', ',', 'people', 'online', ',', 'resilient', 'misinformation', '?', '”', 'two-minute', 'clips', 'demonstrate', 'tactics', 'show', 'headlines', ',', 'social', 'media', 'posts', ',', 'make', 'person', 'believe', 'something', '’', 'true', '.', '’', 'surprisingly', 'effective', '.', 'subjects', 'viewed', 'videos', 'found', 'significantly', 'better', 'distinguishing', 'false', 'claims', 'accurate', 'information', 'tested', 'researchers', '.', 'positive', 'results', 'occurred', 'experiment', 'replicated', 'youtube', ',', 'nearly', '1', 'million', 'people', 'viewed', 'videos', '.', 'researchers', 'investigating', 'long', 'effects', 'last', ',', 'whether', '“', 'booster', '”', 'videos', 'help', 'sustain', 'benefits', '.', 'earlier', 'findings', 'suggested', 'online', 'games', 'tutorials', 'teach', 'critical', 'thinking', 'skills', 'also', 'improve', 'resiliency', 'misinformation', '.', 'videos', ',', 'could', 'played', 'alongside', 'online', 'advertisements', ',', 'likely', 'reach', 'many', 'people', ',', 'said', 'jon', 'roozenbeek', ',', 'cambridge', 'university', 'professor', 'one', 'authors', 'study', '.', 'authors', 'included', 'researchers', 'university', 'bristol', 'u.k.', 'university', 'western', 'australia', '.', 'google', '’', 'effort', 'one', 'largest', 'real-world', 'tests', 'pre-bunking', 'far', '.', 'videos', 'released', 'youtube', ',', 'facebook', 'tiktok', ',', 'poland', ',', 'czech', 'republic', 'slovakia', '.', 'three', 'countries', 'accepted', 'large', 'numbers', 'ukrainian', 'refugees', 'citizens', 'could', 'vulnerable', 'misinformation', 'ref ...

# %% [markdown]
# PART OF SPEECH TAGGING

# %%
tagged = nltk.pos_tag(filtered)
print(tagged)
# Out:
# [('soon', 'RB'), ('russian', 'JJ'), ('invasion', 'NN'), (',', ','), ('hoaxes', 'NNS'), ('began', 'VBD'), ('.', '.'), ('ukrainian', 'JJ'), ('refugees', 'NNS'), ('taking', 'VBG'), ('jobs', 'NNS'), (',', ','), ('committing', 'VBG'), ('crimes', 'NNS'), ('abusing', 'VBG'), ('handouts', 'NNS'), ('.', '.'), ('misinformation', 'NN'), ('spread', 'NN'), ('rapidly', 'RB'), ('online', 'VBD'), ('throughout', 'IN'), ('eastern', 'JJ'), ('europe', 'NN'), (',', ','), ('sometimes', 'RB'), ('pushed', 'JJ'), ('moscow', 'NN'), ('effort', 'NN'), ('destabilize', 'NN'), ('neighbors', 'NNS'), ('.', '.'), ('’', 'VB'), ('kind', 'NN'), ('swift', 'JJ'), ('spread', 'NN'), ('falsehoods', 'NNS'), ('blamed', 'VBD'), ('many', 'JJ'), ('countries', 'NNS'), ('increased', 'VBD'), ('polarization', 'NN'), ('erosion', 'NN'), ('trust', 'NN'), ('democratic', 'JJ'), ('institutions', 'NNS'), (',', ','), ('journalism', 'NN'), ('science', 'NN'), ('.', '.'), ('countering', 'VBG'), ('stopping', 'VBG'), ('misinformation', 'NN'), ('proven', 'RB'), ('elusive', 'JJ'), ('.', '.'), ('new', 'JJ'), ('findings', 'NNS'), ('university', 'NN'), ('researchers', 'NNS'), ('google', 'VBP'), (',', ','), ('however', 'RB'), (',', ','), ('reveal', 'VBP'), ('one', 'CD'), ('promising', 'NN'), ('responses', 'NNS'), ('misinformation', 'NN'), ('may', 'MD'), ('also', 'RB'), ('one', 'CD'), ('simplest', 'NN'), ('.', '.'), ('paper', 'NN'), ('published', 'VBN'), ('wednesday', 'JJ'), ('journal', 'JJ'), ('science', 'NN'), ('advances', 'NNS'), (',', ','), ('researchers', 'NNS'), ('detail', 'VBP'), ('short', 'JJ'), ('online', 'NN'), ('videos', 'NNS'), ('teach', 'VBP'), ('basic', 'JJ'), ('critical', 'JJ'), ('thinking', 'NN'), ('skills', 'NNS'), ('make', 'VBP'), ('people', 'NNS'), ('better', 'RBR'), ('able', 'JJ'), ('resist', 'JJ'), ('misinformation', 'NN'), ('.', '.'), ('researchers', 'NNS'), ('created', 'VBD'), ('series', 'NN'), ('videos', 'NNS'), ('similar', 'JJ'), ('public', 'JJ'), ('service', 'NN'), ('announcement', 'NN'), ('focused', 'VBD'), ('specific', 'JJ'), ('misinformation', 'NN'), ('techniques', 'NNS'), ('—', 'VBP'), ('characteristics', 'NNS'), ('seen', 'VBN'), ('many', 'JJ'), ('common', 'JJ'), ('false', 'JJ'), ('claims', 'NNS'), ('include', 'VBP'), ('emotionally', 'RB'), ('charged', 'VBN'), ('language', 'NN'), (',', ','), ('personal', 'JJ'), ('attacks', 'NNS'), ('false', 'JJ'), ('comparisons', 'NNS'), ('two', 'CD'), ('unrelated', 'JJ'), ('items', 'NNS'), ('.', '.'), ('researchers', 'NNS'), ('gave', 'VBD'), ('people', 'NNS'), ('series', 'NN'), ('claims', 'VBZ'), ('found', 'VBN'), ('watched', 'VBD'), ('videos', 'NNS'), ('significantly', 'RB'), ('better', 'RBR'), ('distinguishing', 'VBG'), ('false', 'JJ'), ('information', 'NN'), ('accurate', 'NN'), ('information', 'NN'), ('.', '.'), ('’', 'NN'), ('approach', 'NN'), ('called', 'VBN'), ('“', 'CD'), ('pre-bunking', 'JJ'), ('”', 'NNP'), ('builds', 'VBZ'), ('years', 'NNS'), ('research', 'NN'), ('idea', 'NN'), ('known', 'VBN'), ('inoculation', 'NN'), ('theory', 'NN'), ('suggests', 'VBZ'), ('exposing', 'VBG'), ('people', 'NNS'), ('misinformation', 'NN'), ('works', 'VBZ'), (',', ','), ('using', 'VBG'), ('harmless', 'NN'), (',', ','), ('fictional', 'JJ'), ('examples', 'NNS'), (',', ','), ('boost', 'NN'), ('defenses', 'NNS'), ('false', 'JJ'), ('claims', 'NNS'), ('.', '.'), ('findings', 'NNS'), ('hand', 'NN'), (',', ','), ('google', 'NN'), ('plans', 'NNS'), ('roll', 'VBP'), ('series', 'NN'), ('pre-bunking', 'NN'), ('videos', 'JJ'), ('soon', 'RB'), ('eastern', 'JJ'), ('europe', 'NN'), ('focused', 'VBD'), ('scapegoating', 'NN'), (',', ','), ('seen', 'VBN'), ('much', 'JJ'), ('misinformation', 'NN'), ('ukrainian', 'JJ'), ('refugees', 'NNS'), ('.', '.'), ('focus', 'VB'), ('chosen', 'JJ'), ('jigsaw', 'NN'), (',', ','), ('division', 'NN'), ('google', 'NN'), ('works', 'VBZ'), ('find', 'VBP'), ('new', 'JJ'), ('ways', 'NNS'), ('address', 'JJ'), ('misinformation', 'NN'), ('extremism', 'NN'), ('.', '.'), ('“', 'JJ'), ('spent', 'JJ'), ('quite', 'RB'), ('bit', 'JJ'), ('time' ...

# %% [markdown]
# LEMMATIZATION

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatized = [lemmatizer.lemmatize(word) for word in filtered]
print(lemmatized)
# Out:
# ['soon', 'russian', 'invasion', ',', 'hoax', 'began', '.', 'ukrainian', 'refugee', 'taking', 'job', ',', 'committing', 'crime', 'abusing', 'handout', '.', 'misinformation', 'spread', 'rapidly', 'online', 'throughout', 'eastern', 'europe', ',', 'sometimes', 'pushed', 'moscow', 'effort', 'destabilize', 'neighbor', '.', '’', 'kind', 'swift', 'spread', 'falsehood', 'blamed', 'many', 'country', 'increased', 'polarization', 'erosion', 'trust', 'democratic', 'institution', ',', 'journalism', 'science', '.', 'countering', 'stopping', 'misinformation', 'proven', 'elusive', '.', 'new', 'finding', 'university', 'researcher', 'google', ',', 'however', ',', 'reveal', 'one', 'promising', 'response', 'misinformation', 'may', 'also', 'one', 'simplest', '.', 'paper', 'published', 'wednesday', 'journal', 'science', 'advance', ',', 'researcher', 'detail', 'short', 'online', 'video', 'teach', 'basic', 'critical', 'thinking', 'skill', 'make', 'people', 'better', 'able', 'resist', 'misinformation', '.', 'researcher', 'created', 'series', 'video', 'similar', 'public', 'service', 'announcement', 'focused', 'specific', 'misinformation', 'technique', '—', 'characteristic', 'seen', 'many', 'common', 'false', 'claim', 'include', 'emotionally', 'charged', 'language', ',', 'personal', 'attack', 'false', 'comparison', 'two', 'unrelated', 'item', '.', 'researcher', 'gave', 'people', 'series', 'claim', 'found', 'watched', 'video', 'significantly', 'better', 'distinguishing', 'false', 'information', 'accurate', 'information', '.', '’', 'approach', 'called', '“', 'pre-bunking', '”', 'build', 'year', 'research', 'idea', 'known', 'inoculation', 'theory', 'suggests', 'exposing', 'people', 'misinformation', 'work', ',', 'using', 'harmless', ',', 'fictional', 'example', ',', 'boost', 'defense', 'false', 'claim', '.', 'finding', 'hand', ',', 'google', 'plan', 'roll', 'series', 'pre-bunking', 'video', 'soon', 'eastern', 'europe', 'focused', 'scapegoating', ',', 'seen', 'much', 'misinformation', 'ukrainian', 'refugee', '.', 'focus', 'chosen', 'jigsaw', ',', 'division', 'google', 'work', 'find', 'new', 'way', 'address', 'misinformation', 'extremism', '.', '“', 'spent', 'quite', 'bit', 'time', 'energy', 'studying', 'problem', ',', '”', 'said', 'beth', 'goldberg', ',', 'jigsaw', '’', 'head', 'research', 'one', 'author', 'paper', '.', '“', 'started', 'thinking', ':', 'make', 'user', ',', 'people', 'online', ',', 'resilient', 'misinformation', '?', '”', 'two-minute', 'clip', 'demonstrate', 'tactic', 'show', 'headline', ',', 'social', 'medium', 'post', ',', 'make', 'person', 'believe', 'something', '’', 'true', '.', '’', 'surprisingly', 'effective', '.', 'subject', 'viewed', 'video', 'found', 'significantly', 'better', 'distinguishing', 'false', 'claim', 'accurate', 'information', 'tested', 'researcher', '.', 'positive', 'result', 'occurred', 'experiment', 'replicated', 'youtube', ',', 'nearly', '1', 'million', 'people', 'viewed', 'video', '.', 'researcher', 'investigating', 'long', 'effect', 'last', ',', 'whether', '“', 'booster', '”', 'video', 'help', 'sustain', 'benefit', '.', 'earlier', 'finding', 'suggested', 'online', 'game', 'tutorial', 'teach', 'critical', 'thinking', 'skill', 'also', 'improve', 'resiliency', 'misinformation', '.', 'video', ',', 'could', 'played', 'alongside', 'online', 'advertisement', ',', 'likely', 'reach', 'many', 'people', ',', 'said', 'jon', 'roozenbeek', ',', 'cambridge', 'university', 'professor', 'one', 'author', 'study', '.', 'author', 'included', 'researcher', 'university', 'bristol', 'u.k.', 'university', 'western', 'australia', '.', 'google', '’', 'effort', 'one', 'largest', 'real-world', 'test', 'pre-bunking', 'far', '.', 'video', 'released', 'youtube', ',', 'facebook', 'tiktok', ',', 'poland', ',', 'czech', 'republic', 'slovakia', '.', 'three', 'country', 'accepted', 'large', 'number', 'ukrainian', 'refugee', 'citizen', 'could', 'vulnerable', 'misinformation', 'refugee', '.', 'jigsaw', 'ceo', 'yasmin', 'green', 'said', 'work', 'prebunk ...

# %% [markdown]
# NAMED ENTITY RECOGNITION

# %%
neTree = nltk.ne_chunk(tagged)
print(neTree)
# Out:
# (S
#   soon/RB
#   russian/JJ
#   invasion/NN
#   ,/,
#   hoaxes/NNS
#   began/VBD
#   ./.
#   ukrainian/JJ
#   refugees/NNS
#   taking/VBG
#   jobs/NNS
#   ,/,
#   committing/VBG
#   crimes/NNS
#   abusing/VBG
#   handouts/NNS
#   ./.
#   misinformation/NN
#   spread/NN
#   rapidly/RB
#   online/VBD
#   throughout/IN
#   eastern/JJ
#   europe/NN
#   ,/,
#   sometimes/RB
#   pushed/JJ
#   moscow/NN
#   effort/NN
#   destabilize/NN
#   neighbors/NNS
#   ./.
#   ’/VB
#   kind/NN
#   swift/JJ
#   spread/NN
#   falsehoods/NNS
#   blamed/VBD
#   many/JJ
#   countries/NNS
#   increased/VBD
#   polarization/NN
#   erosion/NN
#   trust/NN
#   democratic/JJ
#   institutions/NNS
#   ,/,
#   journalism/NN
#   science/NN
#   ./.
#   countering/VBG
#   stopping/VBG
#   misinformation/NN
#   proven/RB
#   elusive/JJ
#   ./.
#   new/JJ
#   findings/NNS
#   university/NN
#   researchers/NNS
#   google/VBP
#   ,/,
#   however/RB
#   ,/,
#   reveal/VBP
#   one/CD
#   promising/NN
#   responses/NNS
#   misinformation/NN
#   may/MD
#   also/RB
#   one/CD
#   simplest/NN
#   ./.
#   paper/NN
#   published/VBN
#   wednesday/JJ
#   journal/JJ
#   science/NN
#   advances/NNS
#   ,/,
#   researchers/NNS
#   detail/VBP
#   short/JJ
#   online/NN
#   videos/NNS
#   teach/VBP
#   basic/JJ
#   critical/JJ
#   thinking/NN
#   skills/NNS
#   make/VBP
#   people/NNS
#   better/RBR
#   able/JJ
#   resist/JJ
#   misinformation/NN
#   ./.
#   researchers/NNS
#   created/VBD
#   series/NN
#   videos/NNS
#   similar/JJ
#   public/JJ
#   service/NN
#   announcement/NN
#   focused/VBD
#   specific/JJ
#   misinformation/NN
#   techniques/NNS
#   —/VBP
#   characteristics/NNS
#   seen/VBN
#   many/JJ
#   common/JJ
#   false/JJ
#   claims/NNS
#   include/VBP
#   emotionally/RB
#   charged/VBN
#   language/NN
#   ,/,
#   personal/JJ
#   attacks/NNS
#   false/JJ
#   comparisons/NNS
#   two/CD
#   unrelated/JJ
#   items/NNS
#   ./.
#   researchers/NNS
#   gave/VBD
#   people/NNS
#   series/NN
#   claims/VBZ
#   found/VBN
#   watched/VBD
#   videos/NNS
#   significantly/RB
#   better/RBR
#   distinguishing/VBG
#   false/JJ
#   information/NN
#   accurate/NN
#   information/NN
#   ./.
#   ’/NN
#   approach/NN
#   called/VBN
#   “/CD
#   pre-bunking/JJ
#   ”/NNP
#   builds/VBZ
#   years/NNS
#   research/NN
#   idea/NN
#   known/VBN
#   inoculation/NN
#   theory/NN
#   suggests/VBZ
#   exposing/VBG
#   people/NNS
#   misinformation/NN
#   works/VBZ
#   ,/,
#   using/VBG
#   harmless/NN
#   ,/,
#   fictional/JJ
#   examples/NNS
#   ,/,
#   boost/NN
#   defenses/NNS
#   false/JJ
#   claims/NNS
#   ./.
#   findings/NNS
#   hand/NN
#   ,/,
#   google/NN
#   plans/NNS
#   roll/VBP
#   series/NN
#   pre-bunking/NN
#   videos/JJ
#   soon/RB
#   eastern/JJ
#   europe/NN
#   focused/VBD
#   scapegoating/NN
#   ,/,
#   seen/VBN
#   much/JJ
#   misinformation/NN
#   ukrainian/JJ
#   refugees/NNS
#   ./.
#   focus/VB
#   chosen/JJ
#   jigsaw/NN
#   ,/,
#   division/NN
#   google/NN
#   works/VBZ
#   find/VBP
#   new/JJ
#   ways/NNS
#   address/JJ
#   misinformation/NN
#   extremism/NN
#   ./.
#   “/JJ
#   spent/JJ
#   quite/RB
#   bit/JJ
#   time/NN
#   energy/NN
#   studying/VBG
#   problem/NN
#   ,/,
#   ”/NNP
#   said/VBD
#   beth/JJ
#   goldberg/NN
#   ,/,
#   jigsaw/NN
#   ’/NNP
#   head/NN
#   research/NN
#   one/CD
#   authors/VBZ
#   paper/NN
#   ./.
#   “/NN
#   started/VBD
#   thinking/NN
#   :/:
#   make/NN
#   users/NNS
#   ,/,
#   people/NNS
#   online/VBP
#   ,/,
#   resilient/JJ
#   misinformation/NN
#   ?/.
#   ”/JJ
#   two-minute/JJ
#   clips/NNS
#   demonstrate/VBP
#   tactics/NNS
#   show/VBP
#   headlines/NNS
#   ,/,
#   social/JJ
#   media/NNS
#   posts/NNS
#   ,/,
#   make/VBP
#   person/NN
#   believe/VBP
#   something/NN
#   ’/JJ
#   true/JJ
#   ./.
#   ’/JJ
#   surprisingly/RB
#   effective/JJ
#   ./.
#   subjects/NNS
#   viewed/VBD
#   videos/NNS
#   found/VBN
#   significantly/RB
#   better/RBR
#   distinguishing/VBG
#   false/JJ
#   claims/NNS
#   accurate/VBP
#   information/NN
#   tested/VBN
#   researchers/NNS
#   ./.
#   positive/JJ
#   results/NNS
#   occurred/VBD
#   experiment/JJ
#   replicated/VBN
#   youtube/NN
#   ,/,
#   nearly/RB
#   1/CD
#   million/CD
#   people/NNS
#   viewed/VBN
#   videos/NNS
#   ./.
#   researchers/NNS
#   investigating/VBG
#   long/JJ
#   effects/NNS
#   last/JJ
#   ,/,
#   whether/IN
#   “/JJ
#   booster/NN
#   ”/NNP
#   videos/NN
#   help/NN
#   sustain/VB
#   benefits/NNS
#   ./.
#   earlier/JJR
#   findings/NNS
#   suggested/VBD
#   online/JJ
#   games/NNS
#   tutorials/NNS
#   teach/VBP
#   critical/JJ
#   thinking/NN
#   skills/NNS
#   also/RB
#   improve/VBP
#   resiliency/NN
#   misinformation/NN
#   ./.
#   videos/NNS
#   ,/,
#   could/MD
#   played/VB
#   alongside/RP
#   online/JJ
#   advertisements/NNS
#   ,/,
#   likely/RB
#   reach/VBP
#   many/JJ
#   people/NNS
#   ,/,
#   said/VBD
#   jon/NN
#   roozenbeek/NN
#   ,/,
#   cambridge/NN
#   university/NN
#   professor/VBP
#   one/CD
#   authors/NNS
#   study/VBP
#   ./.
#   authors/NNS
#   included/VBD
#   researchers/NNS
#   university/NN
#   bristol/NN
#   u.k./JJ
#   university/NN
#   western/JJ
#   australia/NN
#   ./.
#   google/NN
#   ’/JJ
#   effort/NN
#   one/CD
#   largest/JJS
#   real-world/JJ
#   tests/NNS
#   pre-bunking/VBG
#   far/RB
#   ./.
#   videos/NNS
#   released/VBN
#   youtube/NN
#   ,/,
#   facebook/NN
#   tiktok/NN
#   ,/,
#   poland/NN
#   ,/,
#   czech/JJ
#   republic/JJ
#   slovakia/NN
#   ./.
#   three/CD
#   countries/NNS
#   accepted/VBD
#   large/JJ
#   numbers/NNS
#   ukrainian/JJ
#   refugees/NNS
#   citizens/NNS
#   could/MD
#   vulnerable/VB
#   misinformation/NN
#   refugees/NNS
#   ./.
#   jigsaw/NN
#   ceo/NN
#   yasmin/NN
#   green/NN
#   said/VBD
#   work/NN
#   prebunking/NN
#   intended/VBN
#   complement/NN
#   google/NN
#   ’/NNP
#   efforts/NNS
#   reduce/VB
#   spread/JJ
#   misinformation/NN
#   :/:
#   “/JJ
#   scourge/NN
#   misinformation/NN
#   grows/NNS
#   ,/,
#   ’/NNP
#   lot/NN
#   provide/VBP
#   people/NNS
#   prompts/VBP
#   features/VBZ
#   help/NN
#   stay/VB
#   safe/JJ
#   informed/VBN
#   online./JJ
#   ”/NNP
#   journalistic/JJ
#   fact/NN
#   checks/NNS
#   effective/JJ
#   debunking/VBG
#   particular/JJ
#   piece/NN
#   misinformation/NN
#   ,/,
#   ’/JJ
#   time/NN
#   labor/NN
#   intensive/JJ
#   ./.
#   focusing/VBG
#   characteristics/NNS
#   misinformation/NN
#   general/JJ
#   instead/RB
#   specific/JJ
#   claims/NNS
#   ,/,
#   pre-bunking/JJ
#   videos/NN
#   help/NN
#   person/NN
#   spot/NN
#   false/JJ
#   claims/NNS
#   wider/VBP
#   variety/NN
#   topics/NNS
#   ./.
#   another/DT
#   method/NN
#   ,/,
#   content/JJ
#   moderation/NN
#   social/JJ
#   media/NNS
#   companies/NNS
#   ,/,
#   often/RB
#   inconsistent/JJ
#   ./.
#   platforms/NNS
#   like/IN
#   facebook/NN
#   twitter/NN
#   often/RB
#   remove/VB
#   misinformation/NN
#   violates/NNS
#   rules/NNS
#   ,/,
#   ’/NNP
#   also/RB
#   criticized/VBD
#   failing/VBG
#   ./.
#   platforms/NNS
#   like/IN
#   telegram/NN
#   gab/NN
#   boast/NN
#   largely/RB
#   hands-off/JJ
#   approach/NN
#   misinformation/NN
#   ./.
#   social/JJ
#   media/NNS
#   content/JJ
#   moderation/NN
#   journalistic/JJ
#   fact/NN
#   checks/NNS
#   also/RB
#   run/VBP
#   risk/NN
#   alienating/VBG
#   believe/JJ
#   misinformation/NN
#   ./.
#   might/MD
#   also/RB
#   ignored/VBN
#   people/NNS
#   already/RB
#   distrust/VBP
#   legitimate/JJ
#   news/NN
#   outlets/NNS
#   ./.
#   “/JJ
#   word/NN
#   fact/NN
#   checking/VBG
#   become/JJ
#   politicized/JJ
#   ,/,
#   ”/JJ
#   roozenbeek/NN
#   said/VBD
#   ./.
#   pre-bunking/JJ
#   videos/NN
#   ,/,
#   however/RB
#   ,/,
#   ’/NNP
#   target/NN
#   specific/JJ
#   claims/NNS
#   ,/,
#   make/VBP
#   assertions/NNS
#   true/JJ
#   ./.
#   instead/RB
#   ,/,
#   teach/VB
#   viewer/JJR
#   false/JJ
#   claims/NNS
#   work/VBP
#   general/JJ
#   —/NNP
#   whether/IN
#   ’/NNP
#   claim/NN
#   elections/NNS
#   nasa/VBP
#   ’/JJ
#   moon/NN
#   landings/NNS
#   ,/,
#   latest/JJS
#   outbreak/NN
#   avian/JJ
#   flu/NN
#   ./.
#   transferability/NN
#   makes/VBZ
#   pre-bunking/JJ
#   particularly/RB
#   effective/JJ
#   way/NN
#   confronting/VBG
#   misinformation/NN
#   ,/,
#   according/VBG
#   john/NN
#   cook/NN
#   ,/,
#   research/NN
#   professor/NN
#   australia/VBZ
#   ’/JJ
#   monash/NN
#   university/NN
#   created/VBD
#   online/JJ
#   games/NNS
#   teach/VBP
#   ways/NNS
#   spot/VB
#   misinformation/NN
#   ./.
#   “/CC
#   ’/JJ
#   done/VBN
#   enough/JJ
#   research/NN
#   know/VBP
#   effective/JJ
#   ,/,
#   ”/JJ
#   cook/NN
#   said/VBD
#   ./.
#   “/NNS
#   need/VBP
#   resources/NNS
#   deploy/VB
#   scale/NN
#   ./.
#   ”/NN)

# %% [markdown]
# FREQUENCY DISTRIBUTION

# %%
frequencyDist = nltk.FreqDist(filtered)
print(frequencyDist)
# Out:
# <FreqDist with 332 samples and 618 outcomes>

# %%
print(frequencyDist.most_common(25))
# Out:
# [(',', 44), ('.', 37), ('misinformation', 20), ('’', 15), ('videos', 11), ('people', 8), ('claims', 8), ('“', 8), ('”', 8), ('researchers', 7), ('false', 7), ('online', 6), ('pre-bunking', 6), ('university', 5), ('google', 5), ('one', 5), ('also', 5), ('said', 5), ('refugees', 4), ('teach', 4), ('make', 4), ('research', 4), ('effective', 4), ('ukrainian', 3), ('spread', 3)]

# %% [markdown]
# SENTIMENT ANALYSIS

# %% [markdown]
# Using VADER, NLTK's pretrained sentiment analyzer.

# %%
sia = SentimentIntensityAnalyzer()
sia.polarity_scores("This is an excellent product!")
# Out:
# {'neg': 0.0, 'neu': 0.501, 'pos': 0.499, 'compound': 0.6114}

# %%
# sentiment analysis of AP article
sia.polarity_scores(text)
# Out:
# {'neg': 0.112, 'neu': 0.773, 'pos': 0.116, 'compound': 0.8399}
